# %% [markdown]
# # ІМТР - Завдання 1
# Петровського Андрія Анатолійовича (РТ-01ф)

# %% [markdown]
# ## <a id="theory">Теоретичні питання</a>

# %% [markdown]
# #### <a name="qfirst">**1. Сутність імітаційного моделювання**</a>
# Імітаційне моделювання — це метод дослідження, заснований на тому, що система, яка вивчається, замінюється імітатором і з ним проводяться експерименти з метою отримання інформації про цю систему. Експериментування з імітатором називають імітацією (імітація — це збагнення суті явища, не вдаючись до експериментів на реальному об'єкті).У широкому розумінні імітаційне моделювання -- це процес конструювання моделі реальної системи та експерименти на цій моделі з метою визначення поводження системи або оцінити (в рамках обмежень, зумовлених деяким критерієм чи сукупністю критеріїв) різні стратегії, що забезпечують функціонування цієї системи. А у вузькому розумінні імітаційне моделювання -- це відтворення на ЕОМ реальної виробничої чи організаційної системи. За такого тлумачення термін «імітаційне моделювання» має той самий сенс, що й «машинна імітація» або «машинне моделювання».

# %% [markdown]
# #### <a name="qsecond">**2. Класифікація моделей**</a>
# За мірою повноти опису моделі поділяють на повні, неповні та наближені. Повні моделі адекватні об’єкту у просторі та часі. Для неповного моделювання ця адекватність не зберігається. При наближеному моделюванні беруться до уваги тільки найважливіші аспекти системи.
#
# Залежно від характеру досліджуваних процесів у системі моделі поділяють на детерміновані та стохастичні, статичні та динамічні, неперервні та дискретно-неперервні. Детерміновані моделі відображають процеси, для яких передбачається відсутність випадкових впливів, а у стохастичних враховують випадкові процеси та події. Статичне моделювання застосовується для описування стану системи у фіксований момент, а динамічне — для дослідження поведінки системи у часі. Дискретне, неперервне та дискретно-неперервне моделювання застосовуються для опису процесів, які змінюються у часі.
# Залежно від форми подання об’єкта моделювання поділяють на реальне та абстрактне. При реальному моделюванні використовують можливість дослідження характеристик на реальному об’єкті чи на його частині.
#
# При реальному моделюванні проводять дослідження на реальному об’єкті із подальшим обробленням результатів експерименту на основі теорії подібності. Фізичне моделювання здійснюється через відтворення досліджуваного процесу на моделі, яка в загальному випадку має відмінну від оригіналу природу, але однаковий математичний опис процесу функціонування. Абстрактне моделювання має різноманітні види: наочне, символьне, математичне.
#
# При наочному моделюванні на базі уявлень людини про реальні об’єкти створюють наочні моделі, що відображають явища та процеси, які відбуваються в об’єкті. Символьне моделювання являє собою штучний процес створення об’єкта, який замінює реальний та виражає основні його властивості через певну систему знаків та символів.
#
# Символьне моделювання поділяється, в свою чергу, на мовне та знакове. В основі мовного моделювання лежить деякий тезаурус, який утворюється із набору вхідних понять, причому цей набір має бути фіксованим. Під тезаурусом розуміють словник, одиниці якого містять набори ознак, що характеризують родово-видові зв’язки та згруповані за змістовною близькістю. Між тезаурусом та звичайним словником існують принципові розбіжності. Тезаурус — це словник, який не містять неоднозначних слів. Кожному його слову відповідає лише одне поняття.
#
# <p align="center"><img src="q1_2.png" width="400"/></p>
# <p align="center">Класифікація моделей</p>

# %% [markdown]
# #### <a name="qthird">**3. Переваги та недоліки імітаційного моделювання**</a>
# *Основні перваги імітаційного моделювання при дослідженні складних систем:*
#
# - Можливість досліджувати особливості процесу функціонування системи в будь-яких умовах;
#
# - За рахунок застосування ЕОМ суттєво скорочується тривалість випробувань в порівнянні з натурним експериментом;
#
# - Результати натурних випробувань реальної системи або її частин можна використовувати для проведення імітаційного моделювання;
#
# - Гнучкість варіювання структури, алгоритмів і параметрів модельованої системи при пошуку оптимального варіанта системи;
#
# - Для складних систем - це єдиний практично реалізований метод дослідження процесу функціонування систем.
#
# *Основні недоліки імітаційного моделювання:*
#
# - Для повного аналізу характеристик процесу функціонування систем і пошуку оптимального варіанту потрібно багато разів відтворювати імітаційний експеримент, варіюючи вихідні дані завдання;
#
# - Великі витрати машинного часу.

# %% [markdown]
# #### <a name="qfourth">**4. Мистецтво моделювання**</a>
# Імітаційне моделювання в широкому розумінні - процес конструювання моделі реальної системи та експериментування на цій моделі з метою визначити поводження системи або оцінити (в рамках обмежень, зумовлених деяким критерієм чи сукупністю критеріїв) різні стратегії, що забезпечують функціонування даної системи,
#
# У вужчому розумінні імітаційне моделювання - це відтворення на ЕОМ реальної виробничої чи організаційної системи.
#
# Широке використання імітаційного моделювання стало можливим на певному етапі розвитку інформаційних технологій, тобто засобів і інструментів збору передачі, обробки, зберігання інформації. Серед цих засобів маються на увазі не лише комп'ютери, але й засоби обчислювальної математики, багаторівневі інструменти програмування, системи управління базами даних, банки даних і так далі.
# Моделювання складних систем також можна назвати мистецтвом, ніж звичайним програмним кодом оскільки воно вимагає більшої гнучкості та креативності.

# %% [markdown]
# #### <a name="qfifth">**5. Вимоги до моделі**</a>
# - *незалежність* результатів розв'язання задач від конкретної фізичної інтерпретації елементів моделі;
#
# - *змістовність*, тобто здатність моделі відображати істотні риси і властивості реального процесу, який вивчається і моделюється;
#
# - *дедуктивність*, тобто можливість конструктивного використання моделі для отримання результату;
#
# - *індуктивність* - вивчення причин і наслідків, від окремого до загального, з метою накопичення необхідних знань.

# %% [markdown]
# #### <a name="qsixth">**6. Процес імітації**</a>
# Процес моделювання складається з кількох етапів.
# **На першому етапі** дослідник визначає мету та задачу моделювання.
# **На другому етапі**, виходячи з мети та задачі моделювання, дослідник приступає до вербального опису системи. Опис набору змінних моделі, разом із описом структури системи та формулюванням цілі та задачі дослідження складає концептуальну модель системи. Виходячи з концептуальної моделі системи та з огляду на вибір інструментальних засобів, дослідник робить вибір теоретичної бази, на основі якої буде побудована модель системи. Отже, обравши теоретичну базу моделюnаппя, дослідник має описати систему, що розглядається, обраними елементами формального опису і визначити для них усі необхідні параметри:. Форма.пьне представлення еистеми має вигляд схеми, в якій указані зв'язки між елементами системи та зв'язки із зовнішнім середовищем й указані параметри елементів системи. У формальній моделі міститься також інформація, яким чином будуть знайдені вихідні змінні моделі в результаті моделювання. Наприклад, якщо в якості теоретичної бази моделювання обрані засоби мереж масового обслуговування, формальна модель представляється зображенням мережі масового обслуговування, що складена за умовою задачі, з визначенням числових значень вхідних змінних j параметрів, а також формули розрахунку вихідних: змінних моделі, що є мета моделювання.
# **На третьому етапі** дослідник приступає до створення моделі. Спочатку виконується реалізація моделі за допомогою обраного програмного забезпечення. Потім виконується верифікація моделі, тобто перевірка алгоритму моделювання на відповідність задуму моделювання. Наприклад, змінюють значення вхідних змінних і спостерігають як модель реагує на таке змінювання. Якщо реакція моделі відповідає логіці її функціонування, то модель вважається правильною. Завершується створення моделі перевіркою адекват ності моделі, що полягає у порівнянні значень вихідних змінних об' єкта, що моделюється, і моделі при однакових зuаченнях вхідних змінних. Очевидно, що таку перевірку можна здійснити тільки якщо відомі деякі значення вхідних і вихідних змінних об' єкта.
# **Четвертий етап** - це дослідження моделі. Результати моделювання стають корисними, якщо проведене зміеговне дослідження моделі відповідно до цілі моделювання.
# Експерименти, що проводяться з моделлю, мають бути спочатку сплановані, потім - проведені, і наприкінці - статистично оброблені. Наприклад, якщо при дослідженні технологічного процесу обробки деталей була поставлена мета - виявлення місць накопичення деталей, то у результаті моделювання слід не тільки укюати ці місця накопичення та обсяги накопичення, але й дослідити, які фактори впливають на зменшення накопичення деталей, і запропонувати заходи щодо зменшення обсягів накопичення деталей. Аналіз результатів моделювання складається із оцінки точності результатів моделювання, оцінки стійкості результатів моделювання та оцінки чутливості результатів моделювання.
# Формування висновків та пропозицій є завершальний етап моделювання, на якому підводяться підсумки та висловлюються думки щодо напрямків подальшого дослідження об'єкта моделювання. Звісно, що процес моделювання може бути представлений етапами тільки у звіті про результати моделювання. -У ході моделювання досліднику доводиться неодноразово повертатись до попередніх етапів і уточнювати постановку задачі, формальний опис моделі, алгоритм реалізації або план проведення експериментів, поступового наближаючись до мети.

# %% [markdown]
# #### <a name="qseventh">**7. Постановка задачі**</a>
# Однакові  об'єкти  моделювання  залежно  від цілі та задачі дослідження можуть мати різні моделі. Серед  задач  моделювання  виділимо  такі  задачі:
# - задача  моделювання,
# - задача управління,
# - задача ідентифікації,
# - задача  оптимізації,
# - задача прогнозування.
#
# *Задача моделювання (або пряма задача)* полягає у відшуканні значень вихідних змінних У при відомих значеннях вхідних змінних Х, відомій моделі F та визначених параметрах Р (див.  рис.  1).
# <p align="center"><img src="q1_7_1.png" width="400"/></p>
# <p align="center">Рисунок 1.</p>
#
#
# *Задача  управління  (або  зворотна задача)*  полягає  у  відшуканні  таких  значень вхідних змінних Х, що забезпечують  задані значення вихідних змінних У при відомій моделі  F та фіксованих  значеннях параметрів  Р.
# У  формулюванні  задачі  ідентифікації  відомими  являються  множина  вхідних змінних Х, множина вихідних змінних У та множина моделей F. Потрібно визначити єдину модель  f із множини запропонованих моделей F, і визначити її параметри Р, що забезпечують  при вхідних значеннях Х вихідні значення  У.
# У  постановці  задачі  оптимізації  відомими  являються  модель  F,  множина  можливих вхідних значень Х та критерій оптимізації К, а від дослідника  вимагається знайти  значення  вхідних  змінних  Х, значення параметрів Р та  значення  вихідних змінних У, що  задовольняють  заданому критерію оптимізації К.
# Задача прогнозування формулюється так, що  при відомих для дослідника значеннях вхідних та вихідних значень моделі Xt, Yt до моменту часу t та заданому часі прогнозування Т потрібно визначити модель F та її параметри Р, які забезпечують найліпший прогноз  Yt+T·
# Стисло  визначення  методів моделювання представлені на рис. 2
#
# <p align="center"><img src="q1_7_2.png" width="400"/></p>
# <p align="center"> Рисунок 2. </p>

# %% [markdown]
#  #### <a name="qeighth">**8. Формулювання моделі**</a>
# Задачею системного аналізу являється формування опису системи, що відповідає меті дослідження системи. Опис системи складається з:
# 1) набору вхідних змінних системи із указуванням їх основних характеристик;
# 2) набору вихідних змінних системи, визначення яких забезпечує досягнення
# мети дослідження;
# 3) меж системи із указуванням того, що являється для системи її зовнішнім
# середовищем;
# 4) елементів системи із указуванням їх основних властивостей;
# 5) зв'язків між елементами системи.
# Системний підхід до дослідження систем означає, що дослідник вивчає функціонування системи у цілому, не концентруючи свою увагу на окремих її частинах.Системний підхід грунтується на визнанні факту, що навіть найліпше функціонування окремих підсистем та елементів системи не гарантує найліпшого функціонування всієї системи у цілому, оскільки завжди існує взаємодія між частинами системи.
# Всім системам притаманні характеристики, що являються перепоною на шляху до поліпшення функціонування системи:
# - змінюваність - жодна реальна система не являється статичною впродовж тривалого проміжку часу, тому модель, що будується, має обмежений термін користування;
# - наявність оточуючого середовища - в моделі має бути передбачений вплив зовнішнього середовища, який часто має випадковий характер;
# - противоінтуітивна поведінка - виникає як результат того, що інколи наслідок проявляється пізніше причини;
# - тенденція до погіршення характеристик функціонування - окремі частини системи зношуються, у результаті чого погіршується їх робота, що своєю чергою призводить до не передбачуваних наслідків;
# - взаємозалежність - усі частини системи залежать одна від одної, внаслідок чого погіршення характеристик функціонування однієї частини системи неминуче впливає на характеристики функціонування інших частин системи;
# - організація - існує ієрархія підсистем, що підпорядковується цільовому призначенню системи.
# Будь-яка система об'єктивна і в той же час суб'єктивна з точки зору вибору меж системи та її елементів. Дійсно, одному й тому ж самому об'єктивному процесу дос., дослідник може поставити у відповідність різні системи і тільки досвід дослідника, його інтуїція і 􀄓датність творчо мислити допомагає здійснити вибір між багатьма варіантами і виконати дослідження системи найліпшим способом. Моделі, побудовані із застосуванням системного підходу, отримали назву системних моделей.
# Опис системи разом із указуванням мети та задачі дослідження складає сутність концептуальної моделі системи. Назва "концептуальна" походить від латинського слова conceptio, що означає "сприйняття".
# Умовно можна виділити такі етапи створення концептуальної моделі системи:
# - Визначення цілі дослідження системи (орієнтація).
# - Вибір рівня деталізації системи (стратифікація).
# Визначення елементів системи (деталізація)
# - Визначення впливу зовнішнього середовища (локалізація).
# - Визначення зв 'язків між елементами системи та із зовнішнім середовищем (структуризація).

# %% [markdown]
# #### <a name="qnineth">**9. Перевірка моделі**</p>
# Проте успішне вирішення названих проблем на імітаційних моделях можливе лише на  адекватних моделях. Тому під час дослідження складних економічних систем на імітаційних моделях насамперед слід встановити адекватність моделі реальним об’єктам. У разі неадекватності моделі дослідник ризикує дістати недостовірні результати, а на їх підставі прийти до помилкових висновків. Тому оцінювання адекватності моделі — обов’язковий етап моделювання, який сам по собі може бути великою і складною задачою. Перевірку достовірності моделі називають її *верифікацією* (від лат. verus — істинний і ficatio (facio) — роблю).
# *Адекватна* (від лат. adaquatus — прирівнюваний) імітаційна модель математично і  логічно з певною мірою наближення відображає досліджувану систему. Логічні елементи  моделі відповідають операціям, що виконуються у реальній дійсності, а математичний опис визначає функції, що реалізуються в реальній системі. Ймовірнісні оператори адекватної імітаційної моделі відображають випадковий характер подій реальної системи.
# *Верифікація імітаційної моделі* є перевірка відповідності її поведінки припущеннях експериментатора. Коли модель організована у вигляді обчислювальної програми для комп'ютера, то спочатку виправляють помилки в її записи на алгоритмічній мові, а потім переходять до верифікації. Це перший етап дійсної підготовки до імітаційного експерименту. Підбираються деякі вихідні дані, для яких можуть бути передбачені результати прорахунку. Якщо виявиться, що ЕОМ видає дані, що суперечать тим, які очікувалися при формуванні моделі, значить, модель невірна, тобто не відповідає закладеним у неї очікуванням. У зворотному випадку переходять до наступного етапу перевірки працездатності моделі - її валідації.
# *Валідація* - підтвердження на основі наданням об'єктивних доказів того, що вимоги, призначені для конкретного використання або застосування, виконані. Образно кажучи, валідація - це процедура зіставлення того, що задумано зробити (або ще поки робиться), з тим, що необхідно споживачеві для конкретного застосування, тобто зіставлення планованого або проміжного результату діяльності з поточними вихідними вимогами - "погляд вперед". Дослівний переклад з англійської: validation - це: 1) ратифікація, затвердження, Sync: ratification; 2) легалізація, визнання законної сили, надання юридичної сили.
# Верифікація є інструментом валідації, її частиною. Верифікація триває аж до моменту кодування програми, а валідація здійснюється безпосередньо після. Тому в практиці моделювання з використанням ЕОМ верифікація та валідація моделей завершується після проведення обчислювального експерименту і підтвердження його результатами відповідності як реальним процесам досліджуваного об'єкта, так відповідності конкретним умовам застосовності (або вимогам). Однак в більшості випадків процеси верифікації, валідації, тестування і реалізації перетинаються за часом.
# Використовуються два підходи до валідації програмного забезпечення. Перший підхід, **дедуктивний**, представлений такими напрямами досліджень, як автоматичне доведення теорем, використанням мультимножин і графів, а також різноманітних спеціалізованих алгебр. Програмна система описується в рамках якогось формалізму, після чого виконується суворе математичне доказ володіння даною системою тими чи іншими властивостями. Другий підхід - **модельний**; його послідовники не прагнуть вписати систему в рамки теорії, а замість цього будують модель системи, яку можна розглядати як машину або автомат. Будь-яка вимога до системи перевіряється для кожного можливого стану автомата.

# %% [markdown]
# #### <a name="qtenth">**10. Зосереджені і розподілені системи в телекомунікаціях і радіотехніці** </a>
# Кола з розподiленими параметрами характеризуються iснуванням в них хвильових процесiв, за яких напруга $ u(t,l) $ і струм $ i(t,l) $ змiнюються не тiльки за часом , але i у просторi. Характер змiнювання цих величин у просторi може бути подібним до закону їх змiнювання у часi. Якщо, наприклад, на входi кола дiє синусоїдна ЕРС, то в будь-якiй точцi кола з координатою  значення напруги (струму) повторюється через перiод T: $ u(t,l_{0})=u(t+T,l_{0})$. При цьому в будь-який фiксований момент часу  значення напруги (струму) може повторюватися через деякий просторовий iнтервал $ \Delta l=\lambda : u(t_{0},l)=u(t_{0},l+\lambda ) $, де $\lambda$ -- довжина хвилі
#
# <p align="center"><img src="q10_1.png" width="400"/></p>
#
# Загалом коло характеризується трьома лiнiйними розмiрами x, y, z. Якщо $ x < <  1;y < <  1;z < <  1;$ , то коло є системою з зосередженими параметрами. При цьому, по-перше, час запiзнення електромагнiтних коливань у колi  $\Delta t$ значно менший за перiод коливань генератора, $\Delta t < < T $ ; а по-друге, миттєве значення напруги (струму) однакове у будь-якiй точцi кола.
#
# Iз зменшенням довжини хвилi (iнакше, iз збiльшенням частоти f) вказанi умови не виконуються, i тодi коло буде системою з розподiленими параметрами (хвилеводною системою).
#
# Розглянемо окремий випадок хвилеводних систем, у яких $ x > > \lambda; y < < \lambda; z << \lambda $. Такi системи звуться колами з лiнiйно-розподiленими параметрами або електричними довгими лiнiями. Струм i напруга в лiнiї є функцiями лiнiйної координати x (або l).

# %% [markdown]
# #### <a name="eleventh">**11. Моделі зосереджених і розподілених систем в телекомунікаціях і радіотехніці**</a>
# Моделі з зосередженими параметрами - це моделі систем, параметри яких або не мають просторової протяжності, або цією протяжністю можливо знехтувати. Стан таких систем зазвичай характеризується функцією або скінченним набором функцій, аргументом яких є тільки часова змінна . Як правило, поведінка системи із зосередженими параметрами описується скінченної кількістю звичайних диференціальних рівнянь.
# Моделі з розподіленими параметрами - це моделі систем, характерною рисою яких є просторова протяжність об'єктів, що входять до них. Суттєвим для віднесення системи до класу розподілених є неможливість цією протяжністю знехтувати, не ризикуючи при цьому адекватністю та якістю подання. Стан системи з розподіленими параметрами характеризується функцією або набором функцій кількох змінних. Як правило, однією з таких змінних виступає час, а іншими є координати точок геометричної області, що займає дана система. Поведінку систем з розподіленими параметрами описують диференціальними рівняннями в частинних похідних, диференціально-різницевими, інтегральними, інтегро-диференціальними рівняннями та іншими складними математичними відношеннями [3].
# Позначимо дві такі системи S_d и S_sa (від англійських термінів distributed і stand-alone). Множину елементів в кожній з систем, зазвичай, можна розділити на дві підмножини, V(S_d) = U_d E W_d , V(S_sa) = U_sa  E W_sa. Множини, позначені літерою U, складаються з зосереджених елементів, що займають відносно невеликий обсяг простору і реалізують деяку функцію перетворення. Множини, позначені літерою W, складаються з елементів, що пов'язують деякі зосереджені елементи між собою. Їх основна завдання не перетворення, а передача чогось в системі від одного елемента до іншого. Наприклад, зосередженими елементами можуть бути два комп'ютери, які здійснюють обчислення за деякими алгоритмам. Зв'язуючим елементом може бути кабель, один кінець якого приєднаний до першого комп'ютера, а другий кінець - до другого комп'ютера.
# Часто елементи з множини W мають певну "протяжність" в просторі, наприклад, кабель або кручена пара мають параметр "довжина". Величина цього параметра істотно впливає на функціонування системи. Два інших просторових параметра (обидва вони для кабелю можуть бути позначені терміном «діаметр») або стандартні, або несуттєві. Але в ряді випадків елементи зв'язку мають складну будову, що описується не тільки трьома просторовими характеристиками «довжина», «глибина», «висота», але які вимагають опису як складна геометрична фігура або сукупність фігур.
# Прикладом є передача сигналів за допомогою радіозв'язку на надвисоких частотах. При цьому ефір стає елементом системи. Оскільки радіохвилі поширюються у всіх напрямках, то ефір характеризується трьома просторовими координатами x, y та z. У цих же координатах потрібно розглядати і розташування зосереджених елементів системи, між якими здійснюється зв'язок. У просторі можуть знаходитися предмети, непрозорі для радіохвиль (будинки, гори та ін.). В цьому випадку конфігурація ефіру стає складною, з нього повинні бути «вирізані» непрозорі об'єкти. Як наслідок - не всі зосереджені об'єкти можуть обмінюватися сигналами між собою.
# Додаткове ускладнення елемента зв'язку відбувається, якщо можливості передачі сигналів змінюються з плином часу, як, наприклад, при мобільного зв'язку або при використанні супутників, які не перебувають на геостаціонарній орбіті. Таким чином, елементи з множини W_d можуть бути дуже різними, з великою кількістю характеристик.
# Навпаки, в зосереджених системах елементи з безлічі W_sa описуються просто, а часто взагалі виключаються з розгляду як несуттєві для аналізу властивостей системи. Таким елементом, наприклад, в комп'ютері є набір провідників, що з'єднують процесор з мікросхемами пам'яті. Швидкість роботи комп'ютера залежить від часу виконання команд процесором і часу операцій читання / запису в пам'ять. При малій відстані між процесором і пам'яттю час поширення електричних сигналів по дротах є відносно невеликим, і в математичній моделі системи їм можна знехтувати. Відповідно, елемент зв'язку можна взагалі не включати в модель, а вважати процесор і пам'ять пов'язаними безпосередньо, тобто знаходяться в деякому відношенні.
# Множини зосереджених елементів U_sa и U_d зосередженої і розподіленої систем також можуть відрізнятися. У зосередженої системі функціонування елементів з U_sa інваріантної їх розташування. У розподіленої системі функціонування елементів з U_d  в загальному випадку залежить від їх місця розташування. Ця залежність може бути декількох видів [4]:
# 	залежність від джерел інформації, що мають певне місце розташування;
# 	залежність від поставлених завдань, які повинні вирішуватися елементами системи;
# 	залежність від параметрів середовища в різних точках.

# %% [markdown]
# #### **<a name="qtwelweth">12. Фізичні особливості квантово-механічних систем та їх моделювання**</a >
# Ква́нтова меха́ніка — основоположна фізична теорія, що в описі мікроскопічних об'єктів розширює, уточнює і поєднує результати класичної механіки і класичної електродинаміки. Ця теорія є основою для багатьох напрямів фізики та хімії і охоплює фізику твердого тіла, квантову хімію та фізику елементарних частинок. Термін «квантова» (від лат. quantum — «скільки») пов'язаний з дискретними порціями, які теорія надає певним фізичним величинам, наприклад, енергії електромагнітної хвилі.
#
# Квантова механіка (QM; також відома як квантова фізика, квантова теорія, хвильова механіка або матрична механіка) охоплює теорію квантових полів, і є основоположною теорією фізики, яка описує природу на найменших масштабах атомів і субатомних частинок.
#
# Класична фізика, яка існувала до формулювання теорії відносності та квантової механіки, описує природу на звичайному (макроскопічному) рівні. Більшість теорій класичної фізики можна одержати з квантової механіки як наближення, котре діє в великих (макроскопічних) масштабах. Квантова механіка відрізняється від класичної фізики тим, що енергія, імпульс, імпульс кута та інші величини пов'язаної системи, обмежуються дискретними значеннями.
# Уже впродовж століття існування квантової механіки її передбачення ніколи не були заперечені експериментом. Квантова механіка пояснює принаймні три типи явищ, яких класична механіка та класична електродинаміка не може описати:
#
# - квантування деяких фізичних величин;
# - існування хвильових властивостей у частинок та корпускулярних властивостей у випромінювання, тобто
# - корпускулярно-хвильовий дуалізм; існування змішаних квантових станів.
#
#  $$ \imath \hbar \frac{\partial \psi }{\partial t} = \widehat{H} \psi   $$
#
# У квантовій механіці фізичним величинам не зіставляють якісь конкретні числові значення. Натомість, робиться припущення про розподіл імовірності величин вимірюваного параметра. Як правило, ці імовірності залежатимуть від виду вектора стану в момент проведення вимірювання.
#
# Візьмемо конкретний приклад. Уявимо собі вільну частинку. Її хвильова функція — плоска хвиля. Ми хочемо визначити координату частинки. Власна функція координати частинки є дельта функцією. $ \psi _{x'} = \delta (x-x')$.  Якщо ми тепер зробимо вимірювання, то отримаємо якесь значення х'. При цьому при виконанні вимірювання ми подіяли на систему. Тепер її вектор стану вже не є плоскою хвилею. А є тією самою власною функцією оператора координати частинки.
#
# Іноді система, що нас цікавить, не знаходиться у власному стані жодної вимірюваної нами фізичної величини. Утім, якщо ми спробуємо провести вимірювання, вектор стану миттєво стане власним станом вимірюваної величини. Цей процес має назву колапсу хвильової функції. Якщо ми знаємо вектор стану в момент перед вимірюванням, то в змозі обчислити імовірність колапсу в кожний з можливих власних станів. Наприклад, вільна частинка в нашому попередньому прикладі до вимірювання буде мати хвильову функцію, яка є плоскою хвилею. Коли ми розпочинаємо вимірювання координати частинки, то неможливо передбачити результат, який отримаємо. Після проведення вимірювання, коли ми отримаємо якийсь результат х, хвильова функція колапсує в позицію з власним станом, зосередженим саме в х.
#
# Існують такі експерименти, які неможливо пояснити без залучення квантової механіки. Перший різновид квантових ефектів — квантування певних фізичних величин. Якщо локалізувати вільну частинку з розглянутого вище прикладу у прямокутній потенціальній ямі — області простору розміром L, обмеженій з обох боків нескінченно високим потенціальним бар'єром, то виявиться, що імпульс частинки може мати лише певні дискретні значення $ n\frac{h}{2L} $ де h — стала Планка, а n — довільне натуральне число. Про параметри, які можуть набувати лише дискретних значень кажуть, що вони квантуються. Прикладами квантованих параметрів є також момент імпульсу, повна енергія обмеженої у просторі системи, а також енергія електромагнітного випромінювання певної частоти.
#
# Ще один квантовий ефект — це корпускулярно-хвильовий дуалізм. Можна показати, що за певних умов проведення експерименту, мікроскопічні об'єкти, такі як атоми або електрони, набувають властивостей частинок (тобто можуть бути локалізовані в певній області простору). За інших умов, ті самі об'єкти набувають властивостей хвиль та демонструють такі ефекти, як інтерференція.
#
# Наступний квантовий ефект — це ефект сплутаних квантових станів. В деяких випадках вектор стану системи з багатьох частинок не може бути поданий як сума окремих хвильових функцій, які б відповідали кожній з частинок. В такому випадку кажуть, що стани частинок сплутані. І тоді, вимірювання, яке було проведено лише для однієї частинки, матиме результатом колапс загальної хвильової функції системи, тобто таке вимірювання буде мати миттєвий вплив на хвильові функції інших частинок системи, хай навіть деякі з них знаходяться на значній відстані. (Це не суперечить спеціальній теорії відносності, оскільки передача інформації на відстань в такий спосіб неможлива.)

# %% [markdown]
# ## <a name="practic1">Практична частина</a>

# %% [markdown]
# ### <a name="p1z3">Завдання 3</a>
# ![image](image1.png)
#
# $ \varphi = kl$ – фазова довжина неоднорідності
# $ k=\frac{2\pi }{\lambda } $ – хвилове число
# $ \lambda =\frac{\nu }{f} $ – довжина хвилі
#
# Звідси можна виразити
# $$ \varphi = \frac{2\pi lf}{\nu } $$
#
# Також відомо, що:
# $ F= \frac{f}{f_{0}} \Rightarrow f= F\cdot f_{0} $
# $ l=\frac{\lambda _{0}}{4} $ та $ \lambda _{0} = \frac{\nu }{f_{0}} \Rightarrow f_{0} = \frac{\nu }{\lambda _{0}} $
#
# Тепер можна підставити усі значення для отримання кінцевої формули:
# $$ \varphi = \frac{2\pi \frac{\lambda _{0}}{4}F\frac{\nu }{\lambda _{0}}}{\nu } = \frac{\pi }{2} F $$

# %% [markdown]
# ### <a name="p1z4">Завдання 4</a>

# %%
import numpy as np
pi = np.pi
import matplotlib.ticker as plticker

# %%
def fi(f):
    return pi/2*f

# %%
zb=5
zy=1/5

# %%
import cmath
def z1(f):
    return complex(1,zy*np.tan(fi(f)))/complex(1,1/zy*np.tan(fi(f)))

# %%
def z2(f):
    return complex(1,zb*np.tan(fi(f)))/complex(1,1/zb*np.tan(fi(f)))

# %%
def r(f):
    return (1-z2(f))/(1+z2(f))

# %%
def t(f):
    return np.sqrt(1-pow(abs(r(f)),2))

# %%
def ry(f):
    return (1-z1(f))/(1+z1(f))

# %%
def ty(f):
    return np.sqrt(1-pow(abs(ry(f)),2))

# %% [markdown]
# ### <a name="p1z5">Завдання 5</a>

# %%
ff = np.arange(0,5,0.01)

# %%
rVec = np.vectorize(r)
tVec = np.vectorize(t)
tyVec= np.vectorize(ty)
ryVec= np.vectorize(ry)

# %%
r1v = np.abs(rVec(ff))

# %%
t1v = tVec(ff)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(ff,r1v, label='Коефіцієнт відбиття')
ax.plot(ff,t1v, label='Коефіцієнт проходження')
ax.grid(True)
plt.xlabel('частота')
#ax.ylabel('r')
ax.legend()
ax.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.5)))
ax.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))
#plt.legend()
plt.show()

# %%
ry1v = np.abs(rVec(ff))
ty1v = tVec(ff)

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(ff,ry1v, label='Коефіцієнт відбиття')
ax.plot(ff,ty1v, label='Коефіцієнт проходження')
ax.grid(True)
plt.xlabel('частота')
#ax.ylabel('r')
ax.legend()
ax.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.5)))
ax.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))
#plt.legend()
plt.show()

# %% [markdown]
# ### <a name="p1z8">Завдання 8</a>

# %%
z8=np.arange(3,5.5,0.5)

# %%
def zy8(zz):
    return 1/zz

# %%
l8 = np.arange(0.2,2.1,0.1)

# %%
def fi8(f,ll):
    return pi*ll*f/2

# %%
def z8_1(f,ll,z):
    return complex(1,zy8(z)*np.tan(fi8(f,ll)))/complex(1,1/zy8(z)*np.tan(fi8(f,ll)))

# %%
def z8_2(f,ll,z):
    return complex(1,z*np.tan(fi8(f,ll)))/complex(1,1/z*np.tan(fi8(f,ll)))

# %%
def r8(f,ll,z):
    return (1-z8_2(f,ll,z))/(1+z8_2(f,ll,z))

# %%
def t8(f,ll,z):
    return np.sqrt(1-pow(abs(r8(f,ll,z)),2))

# %%
def ry8(f,ll,z):
    return (1-z8_1(f,ll,z))/(1+z8_1(f,ll,z))

def ty8(f,ll,z):
    return np.sqrt(1-pow(abs(ry8(f,ll,z)),2))

# %%
r8vec = np.vectorize(r8)
t8vec= np.vectorize(t8)

ry8vec = np.vectorize(ry8)
ty8vec= np.vectorize(ty8)

# %%
r8_1d = np.abs(r8vec(ff,1,5))
t8_1d = t8vec(ff,1,5)

ry8_1d = np.abs(ry8vec(ff,1,5))
ty8_1d = ty8vec(ff,1,5)

t8vec(1,1,5)
# Out:
# array(0.38461538)

# %%
ax1 = plt.subplot(111)
ax1.plot(ff,r8_1d, label='К. від. від бар.')
ax1.plot(ff,t8_1d, label='К. пр. від бар.')
ax1.plot(ff, ry8_1d, linestyle=':', linewidth=5, label='К. від. від ями')
ax1.plot(ff, ty8_1d, linestyle=':', linewidth=5, label='К. пр. від ями')
ax1.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.5)))
ax1.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))
plt.grid(True)
plt.xlabel('частота')
ax1.legend()
plt.show()

# %%
t8_1_3 = t8vec(ff,1,3)
t8_1_35 = t8vec(ff,1,3.5)
t8_1_4 = t8vec(ff,1,4.5)

ty8_1_3 = ty8vec(ff,1,3)
ty8_1_35 = ty8vec(ff,1,3.5)
ty8_1_4 = ty8vec(ff,1,4.5)

# %%
ax2 = plt.subplot(111)
ax2.plot(ff,t8_1_3, label='імпеданс - 3')
ax2.plot(ff,ty8_1_3, label='імп. 3 яма', linestyle=':', linewidth=5)
ax2.plot(ff,t8_1_35,  label='імпеданс - 3.5')
ax2.plot(ff,ty8_1_35,  label='імп. 3.5 яма', linestyle=':', linewidth=5)
ax2.plot(ff,t8_1_4,  label='імпеданс - 4')
ax2.plot(ff,ty8_1_4,  label='імп. 4 яма', linestyle=':', linewidth=5)
plt.grid(True)
plt.xlabel('частота')
plt.ylabel('коефіцієнт проходження')
ax2.legend()
ax2.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.5)))
ax2.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))
plt.show()

# %%
t8_07_5 = t8vec(ff,0.7,5)
t8_12_5 = t8vec(ff,1.2,5)
t8_18_5 = t8vec(ff,1.8,5)

ty8_07_5 = ty8vec(ff,0.7,5)
ty8_12_5 = ty8vec(ff,1.2,5)
ty8_18_5 = ty8vec(ff,1.8,5)

# %%
ax3 = plt.subplot(111)
ax3.plot(ff,t8_07_5, label='довжина 0.7 бар.')
ax3.plot(ff,ty8_07_5, label='довжина 0.7 яма', linestyle=':', linewidth=5)
ax3.plot(ff,t8_12_5, label='довжина 1.2 бар.')
ax3.plot(ff,ty8_12_5, label='довжина 1.2 яма', linestyle=':', linewidth=5)
ax3.plot(ff,t8_18_5, label='довжина 1.8 бар')
ax3.plot(ff,ty8_18_5, label='довжина 1.8 яма', linestyle=':', linewidth=5)
plt.grid(True)
ax3.legend()
plt.xlabel('частота')
plt.ylabel('коефіцієнт проходження')
ax3.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.5)))
ax3.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))
plt.show()

# %% [markdown]
# **Висновки.** При збільшенні ширини неоднорідності зменшується частота першого мінімуму. Також вона впливає на періодичність функції - чим більша ширина, тим менший період. Як результат, за допомогою ширини неоднорідності можна керувати честотою мінімуму та резонансного проходження.

# %% [markdown]
# ### <a name="p1z9">Завдання 9</a>

# %%
def rez2(f):
    return np.real(z2(f))

# %%
def imz2(f):
    return np.imag(z2(f))

# %%
def rez2y(f):
    return np.real(z1(f))

def imz2y(f):
    return np.imag(z1(f))

# %%
rez2vec=np.vectorize(rez2)
imze2vec=np.vectorize(imz2)

rez2vecy=np.vectorize(rez2y)
imze2vecy=np.vectorize(imz2y)

# %%
rez2vals = rez2vec(ff)
imz2vals = imze2vec(ff)

rez2valsy = rez2vecy(ff)
imz2valsy = imze2vecy(ff)

# %%
fig, (ax4_1,ax4_2) = plt.subplots(2, figsize=(12,12))
# ax4_1 = plt.subplot(111)
ax4_1.plot(ff,rez2vals, label='дійсна')
ax4_2.plot(ff,rez2valsy, label='дійсна', linestyle=':', linewidth=2)

ax4_1.plot(ff,imz2vals,  label='уявна')
ax4_2.plot(ff,imz2valsy,  label='уявна', linestyle=':', linewidth=2)

ax4_2.legend()
ax4_1.legend()
ax4_1.grid(True)
plt.grid(True)
ax4_1.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.2)))
ax4_1.yaxis.set_major_locator(plticker.MultipleLocator(base=float(2)))
ax4_2.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.2)))
ax4_2.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))
ax4_1.set_ylabel('Барʼєр')
ax4_2.set_ylabel('Яма')

# plt.xlabel('частота')
plt.show()

# %% [markdown]
# **Висновки.** На частоті мінімуму активна частина опору дорівнює 25, а реактивна - 0. На частоті резонансу активна складова дорівнює 1, а реативна - 0. Хвильовий імпеданс середовища складає 1, тобто вхідний імпеданс системи дорівнює вхідному імпедансу суредовища, що задовільняє умовам резонансу.

# %%
np.where(imz2valsy == imz2valsy.max())
ff[187]
# Out:
# 1.87

# %% [markdown]
# ### <a name="p1z10">Завдання 10</a>

# %%
z0 = 1
def zl(f):
    return 2*pi*zb*z0*f/4

def zll(f):
    return complex(1,zl(f))

# %%
zlvec = np.vectorize(zll)

f10_1 = np.arange(0,1.1,0.005)
zlvalues = np.imag(zlvec(f10_1))

# %%
ax5 = plt.subplot(111)
ax5.plot(f10_1, imze2vec(f10_1), label='індуктивність в пункті 9')
ax5.plot(f10_1,zlvalues, label='розрахована індуктивність')
ax5.set_xlabel('Частота')
ax5.set_ylim(0,12.5)
plt.grid(True)
ax5.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))
ax5.yaxis.set_major_locator(plticker.MultipleLocator(base=float(1)))
ax5.legend()
plt.show()

# %%
def zc(f):
    return 2*zy*z0/pi/f

def zcc(f):
    return complex(0,-zc(f))/(complex(1,-zc(f)))

# %%
zcvec = np.vectorize(zcc)
fff = np.arange(0.001,5,0.1)

# %%
zcvalues = np.imag(zcvec(fff))
imz2vals2 = imze2vec(fff)

# %%
def z1im(f):
    return np.imag(z1(f))

# %%
f10_2 = np.arange(0.001,1,0.005)
z1im_vec = np.vectorize(z1im)
z1im_vals = z1im_vec(f10_2)

# %%
ax6 = plt.subplot(111)

ax6.plot(f10_2, z1im_vals, label='уявна частина імпедансу ями')
ax6.plot(f10_2,np.imag(zcvec(f10_2)), label='розрахований імпеданс')
ax6.legend()
ax6.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))
ax6.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.05)))
plt.grid(True)
plt.xlabel('частота')
plt.show()

# %%
z1im_vals[-1]
np.imag(zcvec(f10_2))[-1]
# Out:
# -0.1257798191073313

# %% [markdown]
# ### <a name="p1z11">Завдання 11. Висновки</a>
# 1. Залежності модуля коефіцієнта відбиття та проходження є періодичними функціями з періодом 2F.
# 2. Дані залежності будуть співпадати, як для барʼєра, так і для ями, оскільки вхідні імпендаси будуть комплексно спряженими числами (відповідно модуль буде таким же).
# 3. Точками екстремуму залежності модуля коефіцієнта відбиття є **0.923**, яка буде повторюватися в точках нормованої частоти *2(F+1)*, де F=0,1,2... Точкою мінімуму даної функції є **0**, яка буде повторюватися в точках нормованої частоти *2F*, де F=0,1,2...
# 4. Максимумомом функції коефіцієнта проходження є **1**, який буде у точках нормованої частоти *2F*, де F=0,1,2... Мінімумом є **0.384**, який буде повторюватися в точках нормованої частоти *2(F+1)*, де F=0,1,2...
# 5. При збільшені значення імпедансу барʼєра або ями мінімум коефіцієнта проходження буде зростати. Також при збільшені імпедансу можна помітити, що смуги частот в яких коеф. проходження буде наближений до 1 звужується. На жаль, пояснити це явище я не можу. Можна зазначити, що за допомогою імпадансу можна керувати смугою, де коефіцієнт проходження близький до 1.
# 6. Зростання ширини неоднорідності впливає на періодичність функції - при збільшені ширини пероід буде зменшуватися. Відповідно при зміні періоду функції відбувається зміни частот мінімуму та максимуму.
# 7. На нормованих частотах *2(F+1)* маємо максимум дійсної частини імпедансу від барʼєру, який дорівнює 25. Мінімум буде на нормованих частотах *2F*, який дорівнює **1**. Оскільки імпеданс є нормованим, то відповідно він буде дорівнювати імпедансу зовнішнього середовища. Уявна частина імпедансу барʼєра коливається в значенях від -12 до 12.
# 8. Залежність дійсної частини імпедансу від ями має максимальне значення 1 і спостерігається в точках *2F*, де F=0,1,2... Мінімальне значення дорівнює **0.04** і спостерігається в точках *2(F+1)*. Значення уявної частини в точках *F*, де F=0,1,2... Мінімум буде -0.48, яке уде в точках нормованої частоти *2F+0,13*, а максимум буде 0.48 буде в таких точках *2(F+1) + 0,83*
# 9. Графік уявної частини вхідного імпедансу барʼєру на ділянці 0:0,3 має схожий характер з заданою індуктивністю включеною в коло послідовно
# 10. Графік уявної частини вхідного імпедансу ями має схожий характер з графіком імпедансу заданої ємності включеної паралельно. До значення нормованої частоти 0,08 вони майже збігаються. В точці мінімуму значення уявнох частини ями дорівнює -0,48, а розраховане - -0,5. Відновідно їхня абсолютна різниця дорівнює 0,02. Далі ця різниця починає поступово зростати і на нормованій частоті 1 імпеданси будуть відповідно -0,001 та -0.126, різниця яких буде 0,125

# %% [markdown]
# ## <a name="practic2">Практичне завдання - частина 2</a>

# %% [markdown]
# ### <a name="p2z2">Завдання 2</a>
# $  V = 0.2 еВ = 0.2 \cdot 1.602176565 \cdot 10^{-19} Дж = 3.20435313 \cdot 10^{-20} $
# <br/>
# $ V = 0.2 еВ = 0.2 \cdot 1.78266184 \cdot 10^{-36} = 3.5653236800000002 \cdot 10^{-37} $
# <br/>
# $ a = b = 2 нм = 2 \cdot 10^{-9} м $
# <br/>

# %% [markdown]
# ### <a name="p2z3">Завдання 3</a>

# %%
import math

import numpy as np
me = 9.10938291 * 10**-31
e = 1.602176565 * 10**-19
h = 6.62606957 * 10**-34
h1 = 4.135667669 * 10**-15
Vb = 0.2 * e
Vy = -0.2 * e
hh = h/(2*np.pi)
a = 2 * 10 ** -9
#Vkg = Vb * 1.78266184 * 10**-36

# %%
def z(E,V):
    return np.sqrt((E-V)/E+0j)

# %%
def k(E,V):
    return np.sqrt(2*me*(E-V)+0j)/hh

# %%
def tt(E,V):
    return np.tan(k(E,V) * a)

# %%
def zi(E,V):
    return complex(1,-z(E,V)*tt(E,V))/complex(1,-(z(E,V)**(-1)) * tt(E,V))

# %%
def R(E,V):
    return (1-zi(E,V))/(1+zi(E,V))

# %%
def T(E,V):
    return np.sqrt(1-abs(R(E,V))**2)

# %% [markdown]
# ### <a name="p2z4">Завдання 4</a>

# %%
ffnew = np.arange(0.0001*e,10*Vb, 0.0001*e)

# %%
Rvec = np.vectorize(R)
Tvec = np.vectorize(T)

# %%
Rvals = np.abs(Rvec(ffnew,Vb))
Tvals = Tvec(ffnew,Vb)

Ryvals = np.abs(Rvec(ffnew,Vy))
Tyvals = Tvec(ffnew,Vy)

# %%
import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(2, figsize=(12,12))
# fig = plt.figure()
# ax = plt.subplot(111)
#
plt.grid(True)

ax1.plot(ffnew, Rvals, label='R')
ax1.plot(ffnew, Tvals, label='T')
#ax1.plot(ffnew, Tvals, label='коеф. пh.')
ax1.legend()
ax1.grid()
ax1.set_xlabel('E')
ax1.set_ylabel('Барʼєр')
ax2.plot(ffnew, Ryvals, label='R')
ax2.plot(ffnew, Tyvals, label='T')
ax2.legend()
ax2.set_xlabel('E')
ax2.set_ylabel('Яма')
ax1.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.05 * 10 ** -19)))
ax1.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))
ax2.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.5 * 10 ** -20)))
ax2.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))

plt.grid(True)
ax1.set_xlim(0.0001*e,3*Vb)
ax2.set_xlim(0.0001*e,3.5*Vb)
plt.show()

# %%
firstidx = 2808
secondidx = 5928

np.where(ffnew > 0.40 * 10 ** -19)
RvalSecond = Rvals[firstidx:secondidx]
barFistLocalMax = RvalSecond.max()
barFirstLocalMaxIdx = np.where(RvalSecond == barFistLocalMax)
ffnew[barFirstLocalMaxIdx]

rangeSecondMin1 = np.where(ffnew > 0.90 * 10 ** -19)[0][0]
rangeSecondMin2 = np.where(ffnew < 0.95 * 10 ** -19)[0][-1]
secondMinRange = Rvals[rangeSecondMin1:rangeSecondMin2]
secondMin = secondMinRange.min()
secondMinPoint = np.where(secondMinRange == secondMin)

tfirstMax1 = np.where(ffnew > 4.5 * 10 ** -20)[0][0]
tfirstMax2 = np.where(ffnew < 5 * 10 ** -20)[0][-1]
TvalsRange1 = Tvals[tfirstMax1:tfirstMax2]
TvalsRange1max = TvalsRange1.max()
TvalsRange1maxIdx = np.where(TvalsRange1 == TvalsRange1max)
ffnew[tfirstMax1:tfirstMax2][TvalsRange1maxIdx]

tSecondMin1 = np.where(ffnew > 5 * 10 ** -20)[0][0]
tSecondMin2 = np.where(ffnew < 7 * 10 ** -20)[0][-1]
TvalsRange2 = Tvals[tSecondMin1:tSecondMin2]
TvalsRange2Min = TvalsRange2.min()
TvalsRange2Min
TvalsRange2MinIdx = np.where(TvalsRange2 == TvalsRange2Min)
ffnew[tSecondMin1:tSecondMin2][TvalsRange2MinIdx]

ryFirstMin1 = np.where(ffnew > 0.25 * 10 ** -19)[0][0]
ryFirstMin2 = np.where(ffnew < 0.3 * 10 ** -19)[0][-1]
RyvalsRange1 = Ryvals[ryFirstMin1:ryFirstMin2]
RyvalsRange1Min = RyvalsRange1.min()
RyvalsRange1MinIdx = np.where(RyvalsRange1 == RyvalsRange1Min)
ffnew[ryFirstMin1:ryFirstMin2][RyvalsRange1MinIdx]

rySecondMax1 = np.where(ffnew > 0.45 * 10 ** -19)[0][0]
rySecondMax2 = np.where(ffnew < 0.6 * 10 ** -19)[0][-1]
RyValsRange2 = Ryvals[rySecondMax1:rySecondMax2]
RyValsRange2Max = RyValsRange2.max()
RyValsRange2MaxIdx = np.where(RyValsRange2 == RyValsRange2Max)
ffnew[rySecondMax1:rySecondMax2][RyValsRange2MaxIdx]

rySecondMin1 = np.where(ffnew > 1 * 10 ** -19)[0][0]
rySecondMin2 = np.where(ffnew < 1.05 * 10 ** -19)[0][-1]
RyValsRange3 = Ryvals[rySecondMin1:rySecondMin2]
RyValsRange3Min = RyValsRange3.min()
RyValsRange3MinIdx = np.where(RyValsRange3 == RyValsRange3Min)
ffnew[rySecondMin1:rySecondMin2][RyValsRange3MinIdx]

tyFirstMax1 = np.where(ffnew > 0.2 * 10 ** -19)[0][0]
tyFirstMax2 = np.where(ffnew < 0.3 * 10 ** -19)[0][-1]
tyValsRange1 = Tyvals[tyFirstMax1:tyFirstMax2]
tyValsRange1Max = tyValsRange1.max()
tyValsRange1MaxIdx = np.where(tyValsRange1 == tyValsRange1Max)
ffnew[tyFirstMax1:tyFirstMax2][tyValsRange1MaxIdx]

tySecondMin1 = np.where(ffnew > 0.4 * 10 ** -19)[0][0]
tySecondMin2 = np.where(ffnew < 0.6 * 10 ** -19)[0][-1]
tyValsRange2 = Tyvals[tySecondMin1:tySecondMin2]
tyValsRange2Min = tyValsRange2.min()
tyValsRange2MinIdx = np.where(tyValsRange2 == tyValsRange2Min)
ffnew[tySecondMin1:tySecondMin2][tyValsRange2MinIdx]
# Out:
# array([5.43137856e-20])

# %% [markdown]
# ### <a name="p2z5">Завдання 5</a>

# %% [markdown]
# Запишемо функції для відображення графіків дійсної та уявної частини нормованого імпедансу:

# %%
def rezi(E,V):
    return np.real(zi(E,V))

def imzi(E,V):
    return np.imag(zi(E,V))

# %%
rezivec = np.vectorize(rezi)
imzivec = np.vectorize(imzi)

# %%
fff = np.arange(0.0001*e,10*Vb, 0.0001*e)
rez_vals = rezivec(fff,Vb)
imz_vals = imzivec(fff,Vb)

rezy_vals = rezivec(fff, Vy)
imzy_vals = imzivec(fff, Vy)

# %% [markdown]
# Відобразимо графіки уявної та дійсної складових імпедансу для барʼєру та ями:

# %%
import matplotlib.ticker as plticker
fig2, (ax3,ax4) = plt.subplots(2,figsize=(15,15))
# ax1 = plt.subplot(111)
ax3.plot(fff, rez_vals ,label='Re')
ax3.plot(fff, imz_vals, label='Im')
ax3.grid()
ax3.legend()
ax3.set_ylabel('Барʼєр')
ax3.set_ylim(-3,5)
ax4.plot(fff, rezy_vals, label='Re')
ax4.plot(fff, imzy_vals, label='Im')
ax4.set_ylabel('Яма')
ax4.legend()
ax4_1.legend()
ax4.grid()

ax4.set_ylim(-1,2)
ax3.set_xlim(0,4*Vb)
ax4.set_xlim(0,6*Vb)
ax3.set_ylim(-1,2)
# ax3.set_xlim(0.18,0.3)
intervals = float(0.004)
loc1 = plticker.MultipleLocator(base=intervals)
#ax4.xaxis.set_major_locator(loc1)

#ax4.yaxis.set_major_locator(plticker.MultipleLocator(base=float(10)))
# ax3.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1)))
ax3.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.05 * 10 ** -19)))
ax4.xaxis.set_major_locator(plticker.MultipleLocator(base=float(0.1 * 10 ** -19)))
ax3.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.25)))
ax4.yaxis.set_major_locator(plticker.MultipleLocator(base=float(0.25)))

plt.show()

# %%
kzb1_1 = np.where(fff > 0.45 * 10 **-19)[0][0]
kzb1_2 = np.where(fff < 0.5 * 10 **-19)[0][-1]

imz_valsFirst = imz_vals[kzb1_1:kzb1_2]
imz_valsFirstAbs = np.abs(imz_valsFirst)
imz_valsFirstAbsMin = imz_valsFirstAbs.min()
imz_valsFirstAbsMinIdx = np.where(imz_valsFirstAbs == imz_valsFirstAbsMin)
ffVall = fff[kzb1_1:kzb1_2][imz_valsFirstAbsMinIdx]
ffVall
rez_vals[kzb1_1:kzb1_2][imz_valsFirstAbsMinIdx]
#fff[kzb1_1:kzb1_2][rez_valsFirstIdx]

kzb2_1 = np.where(fff > 0.9 * 10 **-19)[0][0]
kzb2_2 = np.where(fff < 0.95 * 10 **-19)[0][-1]
imz_valsSecond = imz_vals[kzb2_1:kzb2_2]
imz_valsSecondAbs = np.abs(imz_valsSecond)
imz_valsSecondAbsMin = imz_valsSecondAbs.min()
imz_valsSecondAbsMinIdx = np.where(imz_valsSecondAbs == imz_valsSecondAbsMin)
ffVall2 = fff[kzb2_1:kzb2_2][imz_valsSecondAbsMinIdx]
ffVall2

kzy1_1 = np.where(fff > 0.2 * 10 **-19)[0][0]
kzy1_2 = np.where(fff < 0.3 * 10 **-19)[0][-1]
imzy_valsFirst = imzy_vals[kzy1_1:kzy1_2]
imzy_valsFirstAbs = np.abs(imzy_valsFirst)
imzy_valsFirstAbsMin = imzy_valsFirstAbs.min()
imzy_valsFirstAbsMinIdx = np.where(imzy_valsFirstAbs == imzy_valsFirstAbsMin)
ffVally1 = fff[kzy1_1:kzy1_2][imzy_valsFirstAbsMinIdx]
ffVally1

kzy2_1 = np.where(fff > 1 * 10 **-19)[0][0]
kzy2_2 = np.where(fff < 1.1 * 10 **-19)[0][-1]
imzy_valsSecond = imzy_vals[kzy2_1:kzy2_2]
imzy_valsSecond
imzy_valsSecondAbs = np.abs(imzy_valsSecond)
imzy_valsSecondAbsMin = imzy_valsSecondAbs.min()
imzy_valsSecondAbsMinIdx = np.where(imzy_valsSecondAbs == imzy_valsSecondAbsMin)
ffVally2 = fff[kzy2_1:kzy2_2][imz_valsSecondAbsMinIdx]
ffVally2
# Out:
# array([1.02282952e-19])

# %% [markdown]
# ### <a name="p2z6">Завдання 6 </a>

# %% [markdown]
# ## Висновки
# 1. Як видно з графіка, що при нульовій енергії модуль коефіцієнта відбиття  барʼєра дорівнює значенню блтзькому до 1. Потім, починаючи з значення 0.18 еВ, модуль коефіцієнта відбиття починає спадати до 0 на значенні 0,454 еВ. Далі він піднімається до значення 0,337 в точці 1,642 еВ і опускається до $ 5.411 * 10 ^{-5} $ в точці 0,925 еВ.  <br/>
# 2. Залежність коефіцієнта проходження починається з 0 і поступово зростає нелінійною залежністю до 1 в точці 0,471 еВ. Далі він опускається до мінімуму 0,942 в точці 0,611 еВ. Далі графік зростає і набуває значення близьке до 1.
# 3. Залежність модуля коефіцієнта відбиття від ями починається з 1 і опускається до 0 в точці 0,281 еВ. Далі підіймається до максимума 0,216 в точці 0,543 еВ. Потім опускається до 0 в точці 1,035 еВ
# 4. Залежність коефіцієнта проходження від ями починається з 0 і переходить у 1 в точці 0,281 еВ. Далі опускається до локального мінімуму 0,976 в точці 0,543 еВ
# 5. Враховуючи ці дані можна прийти до висновку, що для квантово-механічого барʼєра матимемо повне непроходження хвилі до значення енергії 0,2 еВ - тобто Va. Для кваньово-механічної ями такого не буде.
# 6. Для квантово-механічного барʼєра, починаючи з рівня 0,45 еВ маємо майже повне проходження. Для ями проходження буде з рівнем енергії більшим за 0,2 еВ
# 7. Для залежностей дійсної та уявної частин вхідного імпедансу квантово-механічних барʼєра маємо резонанс у точці 0,471 еВ, де дійсна частина дорівнює нормованому опору 1, а уявна - 0. Наступне резонансне проходження буде у точці 0,922 еВ.
# 8. Для залежностей дійсної та уявної частини вхідного імпудансу квантово-механічої ями маємо резонасне проходження хвилі у точці 0,281 еВ та у точці 1,022 еВ
